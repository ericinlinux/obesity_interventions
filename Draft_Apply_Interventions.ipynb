# %% [markdown]
# # Apply interventions and compare with original results.

# %%
from codes.networkPA import generate_network_PA
from codes.simulatePA import diffuse_behavior_PA
from codes.sim_anneal import get_empirical
from codes.interventions import get_bmi_cat

import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

from mpl_toolkits.mplot3d import axes3d, Axes3D
import numpy as np

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
parameters_all = [0.09420487943939887, 0.005507766256539898]
parameters_gen = [0.058781687689926684, 0.0057354077803888695]
parameters_friend = [0.042624787704548806, 0.0040999256641623405]

# %%
level_f='./'

empirical = get_empirical(level_f=level_f)

graph_all = generate_network_PA(level_f=level_f, label='all')
graph_gen = generate_network_PA(level_f=level_f, label='gen')
graph_friend = generate_network_PA(level_f=level_f, label='friend')
# Out:
# ###############################################################
# Graph generation starting!
# Label: all
# Formula: None
# ###############################################################
#
# Create connections...
# Nodes after connections: # 906
# Edges created #:  9154
#
# Create agents...
# PA
# gender
# age
# class
# env
# obesity classifier
# Removing nodes not in the specified classes...
# Nodes removed for not being in the selected classes: # 455
# Nodes remaining after removal: # 451
# Edges remaining after removal #:  6065
# ###############################################################
# Graph generated successfuly!
# ###############################################################
#
# ###############################################################
# Graph generation starting!
# Label: gen
# Formula: None
# ###############################################################
#
# Create connections...
# Nodes after connections: # 905
# Edges created #:  8304
#
# Create agents...
# PA
# gender
# age
# class
# env
# obesity classifier
# Removing nodes not in the specified classes...
# Nodes removed for not being in the selected classes: # 454
# Nodes remaining after removal: # 451
# Edges remaining after removal #:  5532
# ###############################################################
# Graph generated successfuly!
# ###############################################################
#
# ###############################################################
# Graph generation starting!
# Label: friend
# Formula: None
# ###############################################################
#
# Create connections...
# Nodes after connections: # 897
# Edges created #:  5562
#
# Create agents...
# PA
# gender
# age
# class
# env
# obesity classifier
# Removing nodes not in the specified classes...
# Nodes removed for not being in the selected classes: # 446
# Nodes remaining after removal: # 451
# Edges remaining after removal #:  3700
# ###############################################################
# Graph generated successfuly!
# ###############################################################

# %%
graph_all.nodes(data=True)
# Out:
# NodeDataView({965: {'PA': 1.5839325, 'gender': 1.0, 'age': 12.0, 'class': 67.0, 'env': 0.75, 'bmi': 15.966, 'bmi_cat': 3}, 963: {'PA': 2.177445, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.524074074074074, 'bmi': 18.48, 'bmi_cat': 3}, 966: {'PA': 1.85248575, 'gender': 0.0, 'age': 11.0, 'class': 67.0, 'env': 0.0, 'bmi': 20.077, 'bmi_cat': 3}, 967: {'PA': 1.639701, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.4166666666666667, 'bmi': 18.127, 'bmi_cat': 3}, 968: {'PA': 2.842332, 'gender': 1.0, 'age': 12.0, 'class': 67.0, 'env': 0.75, 'bmi': 20.49, 'bmi_cat': 3}, 971: {'PA': 1.008831, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.4166666666666667, 'bmi': 15.56, 'bmi_cat': 3}, 972: {'PA': 1.059882, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.3333333333333333, 'bmi': 15.932, 'bmi_cat': 3}, 973: {'PA': 0.8391029999999999, 'gender': 1.0, 'age': 12.0, 'class': 67.0, 'env': 0.524074074074074, 'bmi': -1.0, 'bmi_cat': nan}, 974: {'PA': 1.405611, 'gender': 0.0, 'age': 11.0, 'class': 67.0, 'env': 0.0, 'bmi': 15.477, 'bmi_cat': 3}, 975: {'PA': 1.222623, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 1.0, 'bmi': 16.823, 'bmi_cat': 3}, 977: {'PA': 2.250171, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.5833333333333334, 'bmi': 17.613, 'bmi_cat': 3}, 978: {'PA': 2.0522400000000003, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.75, 'bmi': 17.518, 'bmi_cat': 3}, 979: {'PA': 1.2742758, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.5833333333333334, 'bmi': 22.039, 'bmi_cat': 4}, 980: {'PA': 1.616343, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.75, 'bmi': 18.596, 'bmi_cat': 3}, 982: {'PA': 1.301724, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.524074074074074, 'bmi': -1.0, 'bmi_cat': nan}, 983: {'PA': 1.170501, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.0, 'bmi': 16.658, 'bmi_cat': 3}, 985: {'PA': 1.4016330000000001, 'gender': 1.0, 'age': 11.0, 'class': 67.0, 'env': 0.524074074074074, 'bmi': 17.238, 'bmi_cat': 3}, 987: {'PA': 1.880472, 'gender': 0.0, 'age': 12.0, 'class': 67.0, 'env': 0.0, 'bmi': 16.305, 'bmi_cat': 3}, 1084: {'PA': 1.240218, 'gender': 0.0, 'age': 11.0, 'class': 71.0, 'env': 0.5, 'bmi': 21.576999999999998, 'bmi_cat': 4}, 1083: {'PA': 1.526175, 'gender': 0.0, 'age': 11.0, 'class': 71.0, 'env': 0.524074074074074, 'bmi': 14.058, 'bmi_cat': 2}, 1085: {'PA': 1.4138730000000002, 'gender': 0.0, 'age': 11.0, 'class': 71.0, 'env': 0.16666666666666666, 'bmi': 16.144000000000002, 'bmi_cat': 3}, 1086: {'PA': 1.6646782500000001, 'gender': 1.0, 'age': 12.0, 'class': 71.0, 'env': 0.75, 'bmi': 15.841, 'bmi_cat': 3}, 1087: {'PA': 0.7511994000000001, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.4166666666666667, 'bmi': 18.38, 'bmi_cat': 3}, 1090: {'PA': 1.8994950000000002, 'gender': 1.0, 'age': 13.0, 'class': 71.0, 'env': 0.75, 'bmi': 15.796, 'bmi_cat': 2}, 1093: {'PA': 1.5834480000000002, 'gender': 1.0, 'age': 12.0, 'class': 71.0, 'env': 0.25, 'bmi': 18.493, 'bmi_cat': 3}, 1094: {'PA': 1.4229, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.3333333333333333, 'bmi': 13.673, 'bmi_cat': 2}, 1095: {'PA': 1.1308612500000002, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.3333333333333333, 'bmi': 14.915999999999999, 'bmi_cat': 2}, 1097: {'PA': 1.8289313999999999, 'gender': 0.0, 'age': 11.0, 'class': 71.0, 'env': 0.5, 'bmi': 18.177, 'bmi_cat': 3}, 1098: {'PA': 1.3484909999999999, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.524074074074074, 'bmi': 20.125999999999998, 'bmi_cat': 3}, 1099: {'PA': 1.4665662, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.5833333333333334, 'bmi': 19.1, 'bmi_cat': 3}, 1100: {'PA': 0.77253525, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.3333333333333333, 'bmi': 16.915, 'bmi_cat': 3}, 1101: {'PA': 1.2588840000000001, 'gender': 1.0, 'age': 12.0, 'class': 71.0, 'env': 0.524074074074074, 'bmi': 29.71, 'bmi_cat': 5}, 1102: {'PA': 2.0385108, 'gender': 0.0, 'age': 12.0, 'class': 71.0, 'env': 0.0, 'bmi': 22.428, 'bmi_cat': 4}, 11 ...

# %% [markdown]
# # Separate the classes
#
# Identify gender of the nodes.

# %%
# Create a dictionary. Keys are the classes, and the values are list of students
class_list = [67, 71, 72, 74, 77, 78, 79, 81, 83, 86, 100, 101, 103, 121, 122, 125, 
              126, 127, 129, 130, 131, 133, 135, 136, 138, 139]
class_dictionary = {}

for c in class_list:
    class_dictionary[c] = []

for node, key in graph_all.nodes.data('class'):
    class_dictionary[int(key)].append((node, graph_all.nodes[node]['gender'], 
                                       graph_all.nodes[node]['bmi_cat'], 
                                       graph_all.nodes[node]['env']))

# %%
class_dictionary
# Out:
# {67: [(965, 1.0, 3, 0.75),
#   (963, 1.0, 3, 0.524074074074074),
#   (966, 0.0, 3, 0.0),
#   (967, 1.0, 3, 0.4166666666666667),
#   (968, 1.0, 3, 0.75),
#   (971, 1.0, 3, 0.4166666666666667),
#   (972, 1.0, 3, 0.3333333333333333),
#   (973, 1.0, nan, 0.524074074074074),
#   (974, 0.0, 3, 0.0),
#   (975, 0.0, 3, 1.0),
#   (977, 0.0, 3, 0.5833333333333334),
#   (978, 0.0, 3, 0.75),
#   (979, 1.0, 4, 0.5833333333333334),
#   (980, 0.0, 3, 0.75),
#   (982, 0.0, nan, 0.524074074074074),
#   (983, 0.0, 3, 0.0),
#   (985, 1.0, 3, 0.524074074074074),
#   (987, 0.0, 3, 0.0)],
#  71: [(1084, 0.0, 4, 0.5),
#   (1083, 0.0, 2, 0.524074074074074),
#   (1085, 0.0, 3, 0.16666666666666666),
#   (1086, 1.0, 3, 0.75),
#   (1087, 0.0, 3, 0.4166666666666667),
#   (1090, 1.0, 2, 0.75),
#   (1093, 1.0, 3, 0.25),
#   (1094, 0.0, 2, 0.3333333333333333),
#   (1095, 0.0, 2, 0.3333333333333333),
#   (1097, 0.0, 3, 0.5),
#   (1098, 0.0, 3, 0.524074074074074),
#   (1099, 0.0, 3, 0.5833333333333334),
#   (1100, 0.0, 3, 0.3333333333333333),
#   (1101, 1.0, 5, 0.524074074074074),
#   (1102, 0.0, 4, 0.0),
#   (1104, 1.0, 3, 0.5),
#   (1105, 1.0, nan, 0.524074074074074),
#   (1107, 0.0, nan, 0.524074074074074),
#   (1108, 1.0, 3, 0.3333333333333333),
#   (1109, 0.0, 3, 0.16666666666666666)],
#  72: [(1117, 1.0, 3, 0.3333333333333333),
#   (1111, 1.0, 4, 0.75),
#   (1118, 1.0, 3, 0.16666666666666666),
#   (1123, 1.0, nan, 0.524074074074074),
#   (1126, 0.0, nan, 0.524074074074074),
#   (1128, 1.0, 3, 0.9166666666666666),
#   (1137, 0.0, nan, 0.524074074074074),
#   (1112, 0.0, 3, 0.0),
#   (1114, 0.0, 3, 0.9166666666666666),
#   (1115, 0.0, 3, 0.4166666666666667),
#   (1116, 0.0, 3, 0.75),
#   (1119, 0.0, nan, 0.524074074074074),
#   (1120, 0.0, nan, 0.524074074074074),
#   (1121, 0.0, 4, 0.3333333333333333),
#   (1125, 0.0, 3, 0.5),
#   (1130, 0.0, 3, 0.5833333333333334),
#   (1132, 0.0, 3, 0.3333333333333333),
#   (1134, 1.0, nan, 0.524074074074074),
#   (1135, 0.0, 3, 0.25),
#   (1292, 0.0, nan, 0.524074074074074)],
#  74: [(1157, 1.0, nan, 0.524074074074074),
#   (1155, 0.0, 3, 0.524074074074074),
#   (1158, 1.0, 3, 0.524074074074074),
#   (1160, 0.0, 2, 0.524074074074074),
#   (1161, 0.0, 3, 1.3333333333333333),
#   (1163, 0.0, 4, 0.75),
#   (1164, 0.0, 3, 1.3333333333333333),
#   (1162, 1.0, 2, 0.8333333333333334),
#   (1165, 0.0, 3, 0.25),
#   (1168, 1.0, 3, 0.524074074074074),
#   (1169, 1.0, 3, 0.9166666666666666),
#   (1170, 1.0, 2, 1.1666666666666667)],
#  77: [(1264, 1.0, 4, 0.0),
#   (1261, 1.0, 3, 0.5833333333333334),
#   (1266, 1.0, 3, 0.3333333333333333),
#   (1267, 0.0, 3, 0.5833333333333334),
#   (1268, 1.0, 3, 0.5),
#   (1270, 1.0, 2, 0.5833333333333334),
#   (1274, 1.0, 3, 0.4166666666666667),
#   (1280, 1.0, 3, 0.6666666666666666),
#   (1281, 1.0, 3, 0.75),
#   (1283, 1.0, 2, 0.5),
#   (1285, 1.0, 3, 0.25),
#   (1286, 1.0, 3, 0.3333333333333333),
#   (1289, 0.0, 3, 0.5833333333333334),
#   (1290, 1.0, 3, 0.5833333333333334),
#   (1291, 1.0, 2, 0.3333333333333333),
#   (1263, 0.0, 3, 0.0),
#   (1271, 0.0, 3, 0.5833333333333334),
#   (1272, 0.0, 3, 0.8333333333333334),
#   (1278, 0.0, 5, 0.524074074074074)],
#  78: [(1375, 0.0, 4, 0.4166666666666667),
#   (1374, 0.0, 3, 0.5),
#   (1377, 1.0, 3, 0.5833333333333334),
#   (1378, 1.0, 4, 0.4166666666666667),
#   (1379, 0.0, 3, 0.3333333333333333),
#   (1380, 0.0, 3, 0.5833333333333334),
#   (1381, 0.0, 3, 0.5),
#   (1385, 1.0, 3, 0.5),
#   (1386, 0.0, 3, 0.5833333333333334),
#   (1390, 0.0, 3, 0.5),
#   (1391, 1.0, 3, 1.1666666666666667),
#   (1394, 0.0, 3, 0.25),
#   (1396, 0.0, 4, 0.16666666666666666),
#   (1397, 1.0, 2, 1.1666666666666667),
#   (1376, 1.0, 5, 1.3333333333333333),
#   (1382, 1.0, 3, 1.0833333333333333),
#   (1383, 1.0, 3, 0.25),
#   (1389, 0.0, 3, 1.5),
#   (1392, 1.0, 3, 0.3333333333333333),
#   (1393, 1.0, 3, 0.16666666666666666)],
#  79: [(1455, 0.0, nan, 0.8333333333333334),
#   (1452, 1.0, 3, 0.75),
#   (1456, 0.0, 3, 1.25),
#   (1457, 1.0, 2, 0.3333333333333333),
#   (1461, 1.0, 3, 0.3333333333333333),
#   (1463, 1.0, 3, 1.0833333333333333),
#   (1464, 1.0, 3, 0.6666666666666666),
#   (1465, 1.0, 4, 0.5833333333333334),
#   (1466, 1.0, 3, 0.25),
#   (1467, 1.0, 3, 0.0),
#   (1470, 1.0, 3, 0.5),
#   (1471, 1.0, 2, 0.25),
#   (1479, 0.0, 3, 0.5833333333333334),
#   (1480, 0.0, 4, 1.4166666666666667),
#   (1454, 0.0, 3, 0.75),
#   (1459, 0.0, 3, 0.16666666666666666),
#   (1460, 0.0, 3, 0.5),
#   (1468, 0.0, 2, 0.524074074074074),
#   (1469, 0.0, 3, 0.524074074074074),
#   (1472, 0.0, 3, 0.16666666666666666),
#   (1476, 0.0, 3, 0.4166666666666667),
#   (1458, 1.0, 3, 0.16666666666666666),
#   (1473, 0.0, 3, 0.4166666666666667),
#   (1474, 1.0, 3, 0.25),
#   (1477, 1.0, 3, 0.5)],
#  81: [(1347, 1.0, 3, 0.16666666666666666),
#   (1346, 1.0, 4, 1.0833333333333333),
#   (1348, 0.0, 3, 0.524074074074074),
#   (1349, 1.0, 3, 0.75),
#   (1350, 1.0, 4, 0.4166666666666667),
#   (1351, 1.0, 3, 1.0),
#   (1352, 1.0, 3, 0.5),
#   (1357, 1.0, 3, 0.5),
#   (1358, 1.0, 3, 0.75),
#   (1362, 1.0, 3, 0.4166666666666667),
#   (1365, 0.0, 3, 0.0),
#   (1368, 0.0, 3, 0.0),
#   (1369, 1.0, 3, 1.0),
#   (1372, 1.0, 3, 0.8333333333333334),
#   (1355, 0.0, 5, 0.524074074074074),
#   (1359, 0.0, 3, 1.0833333333333333),
#   (1364, 0.0, 3, 0.16666666666666666),
#   (1367, 0.0, 3, 1.0833333333333333),
#   (1370, 0.0, 3, 0.5),
#   (1371, 0.0, 3, 0.6666666666666666),
#   (1373, 0.0, 3, 0.5),
#   (1353, 0.0, 3, 0.75),
#   (1354, 0.0, 3, 0.6666666666666666),
#   (1356, 0.0, 3, 0.5833333333333334),
#   (1361, 1.0, 4, 0.75),
#   (1363, 0.0, 4, 0.0),
#   (1366, 1.0, 3, 0.4166666666666667),
#   (1360, 0.0, 3, 0.75)],
#  83: [(1422, 0.0, 4, 1.0),
#   (1421, 1.0, 3, 0.5833333333333334),
#   (1424, 0.0, 4, 0.6666666666666666),
#   (1425, 1.0, 3, 0.16666666666666666),
#   (1426, 0.0, 3, 0.3333333333333333),
#   (1427, 1.0, 3, 1.0),
#   (1428, 0.0, 3, 1.0),
#   (1429, 1.0, 0, 0.6666666666666666),
#   (1430, 1.0, 2, 0.5),
#   (1431, 0.0, 3, 1.0),
#   (1432, 0.0, 3, 0.8333333333333334),
#   (1433, 0.0, 3, 0.4166666666666667),
#   (1434, 1.0, 3, 0.75),
#   (1435, 1.0, 3, 0.3333333333333333)],
#  86: [(1549, 0.0, 4, 0.5),
#   (1548, 1.0, 3, 0.6666666666666666),
#   (1550, 1.0, 5, 0.75),
#   (1551, 0.0, 3, 0.0),
#   (1552, 0.0, 5, 0.8333333333333334),
#   (1553, 0.0, 2, 0.5),
#   (1554, 1.0, nan, 0.524074074074074),
#   (1555, 1.0, 4, 1.0),
#   (1556, 1.0, 4, 0.25),
#   (1558, 0.0, 3, 0.3333333333333333),
#   (1559, 0.0, 5, 0.75),
#   (1560, 0.0, 4, 0.5),
#   (1561, 0.0, 3, 0.3333333333333333),
#   (1562, 1.0, 4, 0.75),
#   (1563, 1.0, 3, 1.25),
#   (1564, 1.0, 4, 0.524074074074074)],
#  100: [(2004, 0.0, 5, 0.75),
#   (2003, 1.0, 3, 0.0),
#   (2006, 1.0, 4, 0.3333333333333333),
#   (2007, 0.0, nan, 0.524074074074074),
#   (2008, 1.0, 5, 0.3333333333333333),
#   (2009, 0.0, 3, 0.75),
#   (2010, 1.0, 3, 0.524074074074074),
#   (2011, 0.0, 3, 0.75),
#   (2012, 0.0, 4, 0.25),
#   (2013, 1.0, 3, 0.5),
#   (2015, 1.0, 3, 1.0833333333333333),
#   (2016, 0.0, 3, 0.5),
#   (2017, 1.0, 3, 0.8333333333333334),
#   (2018, 0.0, 3, 0.25),
#   (2019, 0.0, nan, 0.524074074074074),
#   (2020, 1.0, 4, 0.524074074074074),
#   (2021, 1.0, nan, 0.524074074074074),
#   (2022, 0.0, 3, 0.3333333333333333),
#   (2023, 1.0, 5, 1.0833333333333333),
#   (3058, 0.0, nan, 0.524074074074074)],
#  101: [(2026, 1.0, 3, 0.5833333333333334),
#   (2025, 1.0, 4, 0.6666666666666666),
#   (2031, 0.0, 5, 0.6666666666666666),
#   (2032, 1.0, 4, 0.9166666666666666),
#   (2034, 0.0, 3, 1.0),
#   (2035, 0.0, 3, 0.8333333333333334),
#   (2036, 0.0, 2, 0.4166666666666667),
#   (2037, 1.0, 5, 0.9166666666666666),
#   (2038, 1.0, 5, 0.9166666666666666),
#   (2039, 1.0, 3, 0.5833333333333334),
#   (2040, 0.0, 3, 0.4166666666666667),
#   (2041, 1.0, 4, 0.75),
#   (2043, 1.0, 3, 1.3333333333333333),
#   (2044, 1.0, 3, 1.1666666666666667),
#   (2045, 1.0, 3, 0.9166666666666666),
#   (2048, 0.0, 3, 0.4166666666666667),
#   (2051, 0.0, 2, 0.524074074074074),
#   (2052, 1.0, 4, 0.6666666666666666)],
#  103: [(2077, 0.0, 3, 0.25),
#   (2076, 0.0, 3, 0.8333333333333334),
#   (2078, 0.0, 3, 0.75),
#   (2079, 0.0, 4, 0.9166666666666666),
#   (2080, 0.0, 3, 0.3333333333333333),
#   (2081, 0.0, 3, 0.0),
#   (2082, 1.0, 2, 0.5833333333333334),
#   (2083, 1.0, 3, 0.3333333333333333),
#   (2084, 1.0, 5, 1.3333333333333333),
#   (2085, 1.0, 3, 0.16666666666666666),
#   (2086, 0.0, 3, 1.25),
#   (2087, 0.0, 4, 0.5833333333333334),
#   (2088, 0.0, 3, 1.1666666666666667),
#   (2089, 0.0, 5, 0.8333333333333334),
#   (2091, 0.0, 3, 0.16666666666666666),
#   (2092, 0.0, 3, 0.0),
#   (2093, 1.0, 3, 0.5833333333333334)],
#  121: [(2581, 0.0, 3, 0.0),
#   (2577, 0.0, 3, 0.75),
#   (2585, 0.0, 3, 0.3333333333333333),
#   (2588, 0.0, 3, 0.524074074074074),
#   (2589, 0.0, 3, 0.3333333333333333),
#   (2594, 0.0, 3, 0.5833333333333334),
#   (2579, 0.0, 3, 0.5833333333333334),
#   (2578, 1.0, 3, 0.6666666666666666),
#   (2580, 1.0, 3, 0.5),
#   (2592, 1.0, nan, 0.524074074074074),
#   (2597, 1.0, 2, 0.75),
#   (2583, 0.0, nan, 0.524074074074074),
#   (2587, 0.0, 4, 0.25),
#   (2590, 0.0, 2, 0.524074074074074)],
#  122: [(2560, 0.0, 3, 0.75),
#   (2559, 0.0, 3, 0.5),
#   (2562, 0.0, 2, 0.3333333333333333),
#   (2564, 0.0, 3, 0.3333333333333333),
#   (2566, 0.0, 3, 0.5),
#   (2567, 0.0, 3, 0.5833333333333334),
#   (2568, 0.0, 3, 0.524074074074074),
#   (2569, 1.0, 3, 0.3333333333333333),
#   (2571, 0.0, 3, 0.3333333333333333),
#   (2573, 0.0, 4, 0.25),
#   (2574, 1.0, 3, 0.25)],
#  125: [(2627, 0.0, nan, 0.524074074074074),
#   (2632, 0.0, 4, 1.0833333333333333),
#   (2628, 1.0, nan, 0.524074074074074),
#   (2631, 1.0, nan, 0.524074074074074),
#   (2633, 1.0, 3, 0.5833333333333334),
#   (2635, 0.0, 4, 0.0),
#   (2638, 1.0, 3, 0.4166666666666667),
#   (2639, 1.0, 3, 0.9166666666666666),
#   (2640, 1.0, 3, 0.4166666666666667),
#   (2641, 1.0, 3, 0.0),
#   (2642, 0.0, 4, 1.0),
#   (2643, 0.0, 4, 1.0),
#   (2644, 0.0, 4, 1.0833333333333333),
#   (2645, 1.0, 3, 0.5833333333333334),
#   (2646, 1.0, 3, 0.8333333333333334),
#   (2649, 0.0, 3, 0.3333333333333333),
#   (2647, 1.0, 3, 0.4166666666666667)],
#  126: [(2652, 0.0, 3, 0.524074074074074),
#   (2650, 1.0, 4, 0.6666666666666666),
#   (2653, 1.0, 3, 0.4166666666666667),
#   (2654, 0.0, 3, 0.5833333333333334),
#   (2656, 0.0, 3, 0.8333333333333334),
#   (2657, 1.0, 3, 0.25),
#   (2658, 0.0, 3, 0.524074074074074),
#   (2659, 0.0, 3, 0.8333333333333334),
#   (2662, 0.0, 5, 0.524074074074074),
#   (2663, 1.0, nan, 0.8333333333333334),
#   (2664, 0.0, nan, 0.524074074074074)],
#  127: [(2668, 1.0, 4, 0.75),
#   (2665, 0.0, nan, 0.5833333333333334),
#   (2669, 0.0, 3, 0.524074074074074),
#   (2670, 0.0, 3, 0.524074074074074),
#   (2671, 0.0, nan, 0.524074074074074),
#   (2673, 1.0, 3, 0.8333333333333334),
#   (2677, 0.0, 3, 0.0),
#   (2678, 0.0, 3, 0.524074074074074),
#   (2679, 0.0, 3, 1.3333333333333333),
#   (2680, 0.0, 3, 0.524074074074074),
#   (2667, 1.0, 4, 0.6666666666666666),
#   (2672, 1.0, 3, 0.524074074074074),
#   (2675, 1.0, nan, 0.524074074074074),
#   (2681, 0.0, 2, 0.5)],
#  129: [(2697, 0.0, 3, 0.4166666666666667),
#   (2696, 0.0, 4, 0.8333333333333334),
#   (2698, 1.0, nan, 0.524074074074074),
#   (2701, 1.0, 3, 0.524074074074074),
#   (2702, 0.0, 3, 0.25),
#   (2704, 0.0, 3, 1.4166666666666667),
#   (2708, 0.0, 4, 0.4166666666666667),
#   (2709, 0.0, 3, 0.5833333333333334),
#   (2710, 1.0, 4, 0.524074074074074)],
#  130: [(2712, 1.0, 3, 0.16666666666666666),
#   (2711, 1.0, 4, 0.524074074074074),
#   (2714, 0.0, 3, 0.5833333333333334),
#   (2716, 1.0, 3, 1.0833333333333333),
#   (2718, 1.0, 3, 0.3333333333333333),
#   (2722, 0.0, 3, 1.0),
#   (2727, 1.0, 3, 0.3333333333333333),
#   (2728, 0.0, 3, 0.5833333333333334),
#   (2729, 1.0, 3, 0.3333333333333333),
#   (2732, 1.0, 3, 0.0),
#   (2735, 1.0, 4, 0.3333333333333333),
#   (2713, 1.0, 3, 0.5833333333333334),
#   (2717, 1.0, 3, 1.5),
#   (2725, 1.0, 4, 0.5833333333333334),
#   (2730, 0.0, 3, 0.75),
#   (2715, 0.0, 3, 0.0),
#   (2719, 0.0, 3, 0.3333333333333333),
#   (2720, 0.0, 3, 0.524074074074074),
#   (2726, 0.0, 3, 0.3333333333333333),
#   (2731, 0.0, 3, 0.25),
#   (2734, 0.0, 3, 0.3333333333333333)],
#  131: [(2887, 0.0, 3, 1.0),
#   (2886, 1.0, 3, 0.16666666666666666),
#   (2888, 0.0, 3, 0.75),
#   (2889, 0.0, 3, 0.3333333333333333),
#   (2890, 0.0, 3, 0.16666666666666666),
#   (2891, 1.0, 2, 0.4166666666666667),
#   (2892, 0.0, 3, 0.3333333333333333),
#   (2893, 0.0, 3, 0.6666666666666666),
#   (2894, 1.0, 3, 0.3333333333333333),
#   (2895, 0.0, 3, 0.8333333333333334),
#   (2999, 0.0, 2, 0.0)],
#  133: [(2901, 1.0, 3, 0.3333333333333333),
#   (2900, 0.0, 3, 0.8333333333333334),
#   (2902, 0.0, 3, 0.0),
#   (2903, 1.0, 4, 0.524074074074074),
#   (2904, 1.0, 3, 0.0),
#   (2905, 0.0, 4, 0.5),
#   (2906, 0.0, 3, 0.524074074074074),
#   (2910, 1.0, 3, 0.4166666666666667),
#   (2912, 0.0, 3, 0.16666666666666666),
#   (2914, 0.0, nan, 0.524074074074074),
#   (2915, 1.0, 3, 0.6666666666666666),
#   (3003, 0.0, 3, 0.16666666666666666),
#   (3005, 0.0, 3, 0.16666666666666666),
#   (2908, 1.0, 3, 0.3333333333333333),
#   (2909, 1.0, 3, 0.3333333333333333),
#   (2911, 1.0, 3, 0.3333333333333333),
#   (2916, 1.0, 3, 0.3333333333333333),
#   (3001, 1.0, 3, 0.16666666666666666),
#   (3002, 1.0, 2, 0.4166666666666667),
#   (3004, 1.0, 3, 0.4166666666666667)],
#  135: [(2918, 1.0, 2, 0.3333333333333333),
#   (2917, 0.0, 3, 0.6666666666666666),
#   (2919, 1.0, 3, 0.5),
#   (2920, 1.0, 2, 0.16666666666666666),
#   (2921, 0.0, 3, 0.0),
#   (2922, 0.0, 3, 0.16666666666666666),
#   (2923, 0.0, 3, 1.0),
#   (2924, 1.0, 3, 0.3333333333333333),
#   (2925, 1.0, 2, 0.6666666666666666),
#   (2926, 0.0, 3, 0.16666666666666666),
#   (2927, 1.0, 2, 0.4166666666666667),
#   (2928, 1.0, 3, 0.5),
#   (2929, 0.0, 3, 0.3333333333333333),
#   (2930, 1.0, 2, 0.16666666666666666),
#   (2931, 1.0, 3, 0.5833333333333334),
#   (2932, 1.0, 3, 0.0),
#   (2933, 0.0, 3, 0.75),
#   (3000, 0.0, 3, 0.0)],
#  136: [(2759, 0.0, 3, 0.524074074074074),
#   (2758, 0.0, 4, 0.524074074074074),
#   (2760, 1.0, nan, 0.524074074074074),
#   (2761, 0.0, 3, 0.524074074074074),
#   (2762, 1.0, 3, 0.524074074074074),
#   (2764, 1.0, 4, 0.524074074074074),
#   (2765, 1.0, 4, 0.524074074074074),
#   (2767, 1.0, 3, 0.524074074074074),
#   (2768, 1.0, 3, 0.524074074074074),
#   (2771, 1.0, 3, 0.524074074074074),
#   (2773, 1.0, 3, 0.524074074074074),
#   (2774, 0.0, 3, 0.524074074074074),
#   (2776, 1.0, 3, 0.524074074074074),
#   (2777, 0.0, 3, 0.524074074074074),
#   (2778, 0.0, 3, 0.524074074074074),
#   (2779, 1.0, 3, 0.524074074074074),
#   (2780, 0.0, 3, 0.524074074074074),
#   (2782, 0.0, 3, 0.524074074074074),
#   (2783, 0.0, 3, 0.524074074074074)],
#  138: [(2812, 1.0, 3, 0.4166666666666667),
#   (2811, 0.0, 3, 0.3333333333333333),
#   (2813, 1.0, 3, 0.3333333333333333),
#   (2814, 1.0, 2, 0.3333333333333333),
#   (2816, 1.0, 3, 0.3333333333333333),
#   (2818, 1.0, 4, 0.16666666666666666),
#   (2819, 1.0, 3, 0.8333333333333334),
#   (2820, 0.0, 3, 0.0),
#   (2822, 1.0, 3, 0.5833333333333334),
#   (2823, 1.0, 4, 0.0),
#   (2824, 1.0, 3, 0.4166666666666667),
#   (2827, 1.0, 3, 0.0),
#   (2829, 0.0, 3, 0.16666666666666666),
#   (2830, 0.0, 3, 0.5),
#   (2831, 0.0, 3, 0.0),
#   (2832, 1.0, 4, 0.16666666666666666),
#   (2833, 0.0, 3, 0.75),
#   (2834, 0.0, 4, 0.524074074074074),
#   (2825, 1.0, 3, 0.4166666666666667),
#   (2828, 1.0, 4, 0.0)],
#  139: [(2838, 1.0, 3, 0.5),
#   (2835, 1.0, 3, 0.524074074074074),
#   (2839, 0.0, 3, 0.4166666666666667),
#   (2840, 0.0, 3, 0.524074074074074),
#   (2841, 1.0, 4, 0.16666666666666666),
#   (2843, 1.0, 2, 0.3333333333333333),
#   (2844, 1.0, 2, 0.524074074074074),
#   (2845, 0.0, 3, 0.524074074074074),
#   (2848, 1.0, 3, 0.524074074074074),
#   (2849, 0.0, 3, 0.0),
#   (2850, 1.0, 2, 0.524074074074074),
#   (2852, 1.0, 2, 0.524074074074074),
#   (2853, 1.0, 3, 0.4166666666666667),
#   (2857, 1.0, 3, 0.16666666666666666),
#   (2858, 1.0, 3, 0.0),
#   (2859, 1.0, 4, 0.524074074074074),
#   (2862, 0.0, 3, 0.5),
#   (2863, 0.0, 3, 1.0833333333333333),
#   (2864, 1.0, nan, 0.524074074074074)]}

# %%
print('-------------------------------------------------------------------------')
print('Class \t Boys(%) \t Obese (5) \tOverweight (4) \tBad env (>1)')
print('-------------------------------------------------------------------------')
for c, data in class_dictionary.items():
    genders = [item[1] for item in data]
    bmi_cat = [item[2] for item in data]
    env = [item[3] for item in data]
    
    boys_p = genders.count(0)/len(genders)*100.0
    obese_count = bmi_cat.count(5)
    overweighted_count = bmi_cat.count(4)
    bad_env = len([item for item in env if item > 1])
    
    print('{0} \t {1:.2f} \t\t {2:.2f} \t\t {3:.2f} \t\t {4:.2f}'.format(
        c, boys_p, obese_count, overweighted_count, bad_env))
# Out:
# -------------------------------------------------------------------------
# Class 	 Boys(%) 	 Obese (5) 	Overweight (4) 	Bad env (>1)
# -------------------------------------------------------------------------
# 67 	 50.00 		 0.00 		 1.00 		 0.00
# 71 	 65.00 		 1.00 		 2.00 		 0.00
# 72 	 70.00 		 0.00 		 2.00 		 0.00
# 74 	 50.00 		 0.00 		 1.00 		 3.00
# 77 	 31.58 		 1.00 		 1.00 		 0.00
# 78 	 50.00 		 1.00 		 3.00 		 5.00
# 79 	 48.00 		 0.00 		 2.00 		 3.00
# 81 	 53.57 		 1.00 		 4.00 		 3.00
# 83 	 50.00 		 0.00 		 2.00 		 0.00
# 86 	 50.00 		 3.00 		 6.00 		 1.00
# 100 	 50.00 		 3.00 		 3.00 		 2.00
# 101 	 38.89 		 3.00 		 4.00 		 2.00
# 103 	 70.59 		 2.00 		 2.00 		 3.00
# 121 	 71.43 		 0.00 		 1.00 		 0.00
# 122 	 81.82 		 0.00 		 1.00 		 0.00
# 125 	 41.18 		 0.00 		 5.00 		 2.00
# 126 	 63.64 		 1.00 		 1.00 		 0.00
# 127 	 64.29 		 0.00 		 2.00 		 1.00
# 129 	 66.67 		 0.00 		 3.00 		 1.00
# 130 	 47.62 		 0.00 		 3.00 		 2.00
# 131 	 72.73 		 0.00 		 0.00 		 0.00
# 133 	 40.00 		 0.00 		 2.00 		 0.00
# 135 	 44.44 		 0.00 		 0.00 		 0.00
# 136 	 47.37 		 0.00 		 3.00 		 0.00
# 138 	 35.00 		 0.00 		 5.00 		 0.00
# 139 	 31.58 		 0.00 		 2.00 		 1.00

# %% [markdown]
# # Chose the targets
#
# 1. 2 (1 boy)
# 2. 4 (2 boys)
# 3. 6 (3 boys)
# 4. 10%
# 5. 15%
# 6. 20%
