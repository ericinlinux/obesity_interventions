# %%
from codes.networkPA import generate_network_PA
from codes.simulatePA import diffuse_behavior_PA
from codes.sim_anneal import get_empirical
from codes.interventionsPA import apply_intervention_random_nodes
from codes.interventionsPA import apply_interventions_centrality, apply_interventions_high_risk
from codes.interventionsPA import apply_interventions_vulnerability, apply_intervention_max_influence
from codes.results_functions import get_graphs_PA_df

import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
import random
import numpy as np

from mpl_toolkits.mplot3d import axes3d, Axes3D


# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Results for the simulated annealing

# %%
# [threshold, I_PA]
parameters_all = [0.09420487943939887, 0.005507766256539898]
parameters_gen = [0.058781687689926684, 0.0057354077803888695]
parameters_friend = [0.042624787704548806, 0.0040999256641623405]

# %%
level_f='./'

empirical = get_empirical(level_f=level_f)

graph_all = generate_network_PA(level_f=level_f, label='all')
graph_gen = generate_network_PA(level_f=level_f, label='gen')
graph_friend = generate_network_PA(level_f=level_f, label='friend')
# Out:
# ###############################################################
# Graph generation starting!
# Label: all
# Formula: None
# ###############################################################
#
# Nodes removed for not being in the selected classes: # 455
# ###############################################################
# Graph generated successfuly!
# ###############################################################
#
# ###############################################################
# Graph generation starting!
# Label: gen
# Formula: None
# ###############################################################
#
# Nodes removed for not being in the selected classes: # 454
# ###############################################################
# Graph generated successfuly!
# ###############################################################
#
# ###############################################################
# Graph generation starting!
# Label: friend
# Formula: None
# ...

# %% [markdown]
# # Generates graphs with the interventions applied

# %%
# Where the results are going to be saved
results_dict = {'centrality':{'all':{}, 'gen': {}, 'friend':{}},
                'high_risk': {'all':{}, 'gen': {}, 'friend':{}},
                'vulnerability': {'all':{}, 'gen': {}, 'friend':{}},
                'random': {'all':{}, 'gen': {}, 'friend':{}},
                'optimized': {'all':{}, 'gen': {}, 'friend':{}}
               }
results_no_intervention = {}

# %% [markdown]
# # No intervention

# %%
# Run the diffusion model in the interventioned graphs

# No interventions
g_all = graph_all.copy()
diffuse_behavior_PA(graph=g_all, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen = graph_gen.copy()
diffuse_behavior_PA(graph=g_gen, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend = graph_friend.copy()
diffuse_behavior_PA(graph=g_friend, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# Save results
results_no_intervention['all'] = get_graphs_PA_df(g_all)
results_no_intervention['gen'] = get_graphs_PA_df(g_gen)
results_no_intervention['friend'] = get_graphs_PA_df(g_friend)

# %% [markdown]
# ## Centrality

# %%
# Run the diffusion model in the interventioned graphs

# 10%
g_all_10 = apply_interventions_centrality(graph_all.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_all_10, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_10 = apply_interventions_centrality(graph_gen.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_gen_10, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_10 = apply_interventions_centrality(graph_friend.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_friend_10, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# 15%
g_all_15 = apply_interventions_centrality(graph_all.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_all_15, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_15 = apply_interventions_centrality(graph_gen.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_gen_15, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_15 = apply_interventions_centrality(graph_friend.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_friend_15, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)


# 20%
g_all_20 = apply_interventions_centrality(graph_all.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_all_20, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_20 = apply_interventions_centrality(graph_gen.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_gen_20, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_20 = apply_interventions_centrality(graph_friend.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_friend_20, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# Save results
results_dict['centrality']['all'][10] = get_graphs_PA_df(g_all_10)
results_dict['centrality']['all'][15] = get_graphs_PA_df(g_all_15)
results_dict['centrality']['all'][20] = get_graphs_PA_df(g_all_20)

results_dict['centrality']['gen'][10] = get_graphs_PA_df(g_gen_10)
results_dict['centrality']['gen'][15] = get_graphs_PA_df(g_gen_15)
results_dict['centrality']['gen'][20] = get_graphs_PA_df(g_gen_20)

results_dict['centrality']['friend'][10] = get_graphs_PA_df(g_friend_10)
results_dict['centrality']['friend'][15] = get_graphs_PA_df(g_friend_15)
results_dict['centrality']['friend'][20] = get_graphs_PA_df(g_friend_20)
# Out:
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for centrality intervention
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for centrality intervention
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for centrality intervention
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for centrality intervention
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for centrality intervention
# ------------------------------------------------------------------
# ...

# %% [markdown]
# ## High risk

# %%
# 10%
g_all_10 = apply_interventions_high_risk(graph_all.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_all_10, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_10 = apply_interventions_high_risk(graph_gen.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_gen_10, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_10 = apply_interventions_high_risk(graph_friend.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_friend_10, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# 15%
g_all_15 = apply_interventions_high_risk(graph_all.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_all_15, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_15 = apply_interventions_high_risk(graph_gen.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_gen_15, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_15 = apply_interventions_high_risk(graph_friend.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_friend_15, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)


# 20%
g_all_20 = apply_interventions_high_risk(graph_all.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_all_20, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_20 = apply_interventions_high_risk(graph_gen.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_gen_20, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_20 = apply_interventions_high_risk(graph_friend.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_friend_20, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# Save results
results_dict['high_risk']['all'][10] = get_graphs_PA_df(g_all_10)
results_dict['high_risk']['all'][15] = get_graphs_PA_df(g_all_15)
results_dict['high_risk']['all'][20] = get_graphs_PA_df(g_all_20)

results_dict['high_risk']['gen'][10] = get_graphs_PA_df(g_gen_10)
results_dict['high_risk']['gen'][15] = get_graphs_PA_df(g_gen_15)
results_dict['high_risk']['gen'][20] = get_graphs_PA_df(g_gen_20)

results_dict['high_risk']['friend'][10] = get_graphs_PA_df(g_friend_10)
results_dict['high_risk']['friend'][15] = get_graphs_PA_df(g_friend_15)
results_dict['high_risk']['friend'][20] = get_graphs_PA_df(g_friend_20)
# Out:
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ...

# %% [markdown]
# ## Vulnerability

# %%
# 10%
g_all_10 = apply_interventions_vulnerability(graph_all.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_all_10, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_10 = apply_interventions_vulnerability(graph_gen.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_gen_10, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_10 = apply_interventions_vulnerability(graph_friend.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_friend_10, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# 15%
g_all_15 = apply_interventions_vulnerability(graph_all.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_all_15, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_15 = apply_interventions_vulnerability(graph_gen.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_gen_15, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_15 = apply_interventions_vulnerability(graph_friend.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_friend_15, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)


# 20%
g_all_20 = apply_interventions_vulnerability(graph_all.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_all_20, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_20 = apply_interventions_vulnerability(graph_gen.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_gen_20, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_20 = apply_interventions_vulnerability(graph_friend.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_friend_20, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# Save results
results_dict['vulnerability']['all'][10] = get_graphs_PA_df(g_all_10)
results_dict['vulnerability']['all'][15] = get_graphs_PA_df(g_all_15)
results_dict['vulnerability']['all'][20] = get_graphs_PA_df(g_all_20)

results_dict['vulnerability']['gen'][10] = get_graphs_PA_df(g_gen_10)
results_dict['vulnerability']['gen'][15] = get_graphs_PA_df(g_gen_15)
results_dict['vulnerability']['gen'][20] = get_graphs_PA_df(g_gen_20)

results_dict['vulnerability']['friend'][10] = get_graphs_PA_df(g_friend_10)
results_dict['vulnerability']['friend'][15] = get_graphs_PA_df(g_friend_15)
results_dict['vulnerability']['friend'][20] = get_graphs_PA_df(g_friend_20)
# Out:
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for high risk intervention (BMI)
# ------------------------------------------------------------------
# ...

# %% [markdown]
# ## Optimized

# %%
# 10%
g_all_10 = apply_intervention_max_influence(graph_all.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_all_10, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_10 = apply_intervention_max_influence(graph_gen.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_gen_10, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_10 = apply_intervention_max_influence(graph_friend.copy(), perc=0.1)
diffuse_behavior_PA(graph=g_friend_10, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# 15%
g_all_15 = apply_intervention_max_influence(graph_all.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_all_15, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_15 = apply_intervention_max_influence(graph_gen.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_gen_15, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_15 = apply_intervention_max_influence(graph_friend.copy(), perc=0.15)
diffuse_behavior_PA(graph=g_friend_15, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)


# 20%
g_all_20 = apply_intervention_max_influence(graph_all.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_all_20, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)

g_gen_20 = apply_intervention_max_influence(graph_gen.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_gen_20, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)

g_friend_20 = apply_intervention_max_influence(graph_friend.copy(), perc=0.2)
diffuse_behavior_PA(graph=g_friend_20, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)

# Save results
results_dict['optimized']['all'][10] = get_graphs_PA_df(g_all_10)
results_dict['optimized']['all'][15] = get_graphs_PA_df(g_all_15)
results_dict['optimized']['all'][20] = get_graphs_PA_df(g_all_20)

results_dict['optimized']['gen'][10] = get_graphs_PA_df(g_gen_10)
results_dict['optimized']['gen'][15] = get_graphs_PA_df(g_gen_15)
results_dict['optimized']['gen'][20] = get_graphs_PA_df(g_gen_20)

results_dict['optimized']['friend'][10] = get_graphs_PA_df(g_friend_10)
results_dict['optimized']['friend'][15] = get_graphs_PA_df(g_friend_15)
results_dict['optimized']['friend'][20] = get_graphs_PA_df(g_friend_20)
# Out:
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for maximum influence
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for maximum influence
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes for maximum influence
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for maximum influence
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes for maximum influence
# ------------------------------------------------------------------
# ...

# %% [markdown]
# ## Random

# %%
g_all_10_list = []
g_gen_10_list = []
g_friend_10_list = []

g_all_15_list = []
g_gen_15_list = []
g_friend_15_list = []

g_all_20_list = []
g_gen_20_list = []
g_friend_20_list = []

for i in range(100):
    print('\n+++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
    print(i)
    print('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++\n')
    # 10%
    g_all_10 = apply_intervention_random_nodes(graph_all.copy(), perc=0.1)
    diffuse_behavior_PA(graph=g_all_10, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)
    g_all_10_list.append(get_graphs_PA_df(g_all_10))

    g_gen_10 = apply_intervention_random_nodes(graph_gen.copy(), perc=0.1)
    diffuse_behavior_PA(graph=g_gen_10, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)
    g_gen_10_list.append(get_graphs_PA_df(g_gen_10))

    g_friend_10 = apply_intervention_random_nodes(graph_friend.copy(), perc=0.1)
    diffuse_behavior_PA(graph=g_friend_10, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)
    g_friend_10_list.append(get_graphs_PA_df(g_friend_10))


    # 15%
    g_all_15 = apply_intervention_random_nodes(graph_all.copy(), perc=0.15)
    diffuse_behavior_PA(graph=g_all_15, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)
    g_all_15_list.append(get_graphs_PA_df(g_all_15))

    g_gen_15 = apply_intervention_random_nodes(graph_gen.copy(), perc=0.15)
    diffuse_behavior_PA(graph=g_gen_15, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)
    g_gen_15_list.append(get_graphs_PA_df(g_gen_15))

    g_friend_15 = apply_intervention_random_nodes(graph_friend.copy(), perc=0.15)
    diffuse_behavior_PA(graph=g_friend_15, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)
    g_friend_15_list.append(get_graphs_PA_df(g_friend_15))

    # 20%
    g_all_20 = apply_intervention_random_nodes(graph_all.copy(), perc=0.2)
    diffuse_behavior_PA(graph=g_all_20, thres_PA=parameters_all[0], I_PA=parameters_all[1], years=1)
    g_all_20_list.append(get_graphs_PA_df(g_all_20))

    g_gen_20 = apply_intervention_random_nodes(graph_gen.copy(), perc=0.2)
    diffuse_behavior_PA(graph=g_gen_20, thres_PA=parameters_gen[0], I_PA=parameters_gen[1], years=1)
    g_gen_20_list.append(get_graphs_PA_df(g_gen_20))

    g_friend_20 = apply_intervention_random_nodes(graph_friend.copy(), perc=0.2)
    diffuse_behavior_PA(graph=g_friend_20, thres_PA=parameters_friend[0], I_PA=parameters_friend[1], years=1)
    g_friend_20_list.append(get_graphs_PA_df(g_friend_20))
# Out:
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# 0
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++
#
# ------------------------------------------------------------------
# Getting 0.1% of the nodes
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.1% of the nodes
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes
# ------------------------------------------------------------------
# ------------------------------------------------------------------
# Getting 0.15% of the nodes
# ------------------------------------------------------------------
# ...

# %%
g_all_10df = pd.DataFrame(g_all_10_list).mean()
g_all_15df = pd.DataFrame(g_all_15_list).mean()
g_all_20df = pd.DataFrame(g_all_20_list).mean()

g_gen_10df = pd.DataFrame(g_gen_10_list).mean()
g_gen_15df = pd.DataFrame(g_gen_15_list).mean()
g_gen_20df = pd.DataFrame(g_gen_20_list).mean()

g_friend_10df = pd.DataFrame(g_friend_10_list).mean()
g_friend_15df = pd.DataFrame(g_friend_15_list).mean()
g_friend_20df = pd.DataFrame(g_friend_20_list).mean()

# %%
# Save results
results_dict['random']['all'][10] = g_all_10df
results_dict['random']['all'][15] = g_all_15df
results_dict['random']['all'][20] = g_all_20df

results_dict['random']['gen'][10] = g_gen_10df
results_dict['random']['gen'][15] = g_gen_15df
results_dict['random']['gen'][20] = g_gen_20df

results_dict['random']['friend'][10] = g_friend_10df
results_dict['random']['friend'][15] = g_friend_15df
results_dict['random']['friend'][20] = g_friend_20df

# %%
results_no_intervention_df = pd.DataFrame(results_no_intervention)
results_no_intervention_df.columns = ['All (no interventions)', 'Friend (no interventions)', 'General (no interventions)']

# %%
results_final_dict = {(level1_key, level2_key, level3_key): values
            for level1_key, level2_dict in results_dict.items()
            for level2_key, level3_dict in level2_dict.items()
            for level3_key, values      in level3_dict.items()}

# %%
results_df = pd.DataFrame(results_final_dict)
results_df.plot(figsize=((14,8)))

# %%
ylimit = 1.77

plt.figure(figsize=((16,18)))
#plt.suptitle('Network generated with all questions', fontsize=14)
plt.subplot(331)
plt.title('Network generated with all questions', fontsize=14) 
results_df['optimized', 'all', 10].plot(color='red')
results_df['centrality', 'all', 10].plot(color='blue')
results_df['vulnerability', 'all', 10].plot(color='green')
results_df['high_risk', 'all', 10].plot(color='brown')
results_df['random', 'all', 10].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['All (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='10%', loc=4)

plt.subplot(334)
#plt.title('All Questions (15%)')
results_df['optimized', 'all', 15].plot(color='red')
results_df['centrality', 'all', 15].plot(color='blue')
results_df['vulnerability', 'all', 15].plot(color='green')
results_df['high_risk', 'all', 15].plot(color='brown')
results_df['random', 'all', 15].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['All (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='15%', loc=4)

plt.subplot(337)
#plt.title('All Questions (20%)')
results_df['optimized', 'all', 20].plot(color='red')
results_df['centrality', 'all', 20].plot(color='blue')
results_df['vulnerability', 'all', 20].plot(color='green')
results_df['high_risk', 'all', 20].plot(color='brown')
results_df['random', 'all', 20].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['All (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='20%', loc=4)



#################################

plt.subplot(332)
plt.title('Network generated with general questions', fontsize=14) 
#plt.title('Network generated with all questions', fontsize=14)
results_df['optimized', 'gen', 10].plot(color='red')
results_df['centrality', 'gen', 10].plot(color='blue')
results_df['vulnerability', 'gen', 10].plot(color='green')
results_df['high_risk', 'gen', 10].plot(color='brown')
results_df['random', 'gen', 10].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['General (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='10%', loc=4)

plt.subplot(335)
#plt.title('All Questions (15%)')
results_df['optimized', 'gen', 15].plot(color='red')
results_df['centrality', 'gen', 15].plot(color='blue')
results_df['vulnerability', 'gen', 15].plot(color='green')
results_df['high_risk', 'gen', 15].plot(color='brown')
results_df['random', 'gen', 15].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['General (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='15%', loc=4)

plt.subplot(338)
#plt.title('All Questions (20%)')
results_df['optimized', 'gen', 20].plot(color='red')
results_df['centrality', 'gen', 20].plot(color='blue')
results_df['vulnerability', 'gen', 20].plot(color='green')
results_df['high_risk', 'gen', 20].plot(color='brown')
results_df['random', 'gen', 20].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['General (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='20%', loc=4)

############################
plt.subplot(333)
#plt.title('Network generated with all questions', fontsize=14)
plt.title('Network generated with friendship question', fontsize=14) 
results_df['optimized', 'friend', 10].plot(color='red')
results_df['centrality', 'friend', 10].plot(color='blue')
results_df['vulnerability', 'friend', 10].plot(color='green')
results_df['high_risk', 'friend', 10].plot(color='brown')
results_df['random', 'friend', 10].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['Friend (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='10%', loc=4)

plt.subplot(336)
#plt.title('All Questions (15%)')
results_df['optimized', 'friend', 15].plot(color='red')
results_df['centrality', 'friend', 15].plot(color='blue')
results_df['vulnerability', 'friend', 15].plot(color='green')
results_df['high_risk', 'friend', 15].plot(color='brown')
results_df['random', 'friend', 15].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['Friend (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='15%', loc=4)

plt.subplot(339)
#plt.title('All Questions (20%)')
results_df['optimized', 'friend', 20].plot(color='red')
results_df['centrality', 'friend', 20].plot(color='blue')
results_df['vulnerability', 'friend', 20].plot(color='green')
results_df['high_risk', 'friend', 20].plot(color='brown')
results_df['random', 'friend', 20].plot(style='-.', linewidth=2, color='purple')
results_no_intervention_df['Friend (no interventions)'].plot(linewidth=4)
plt.ylim(1.5,ylimit)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(title='20%', loc=4)

plt.tight_layout()

# %%
plt.figure(figsize=((14,22)))
plt.subplot(311)
plt.title('General Questions (10%)')
results_df['optimized', 'gen', 10].plot()
results_df['centrality', 'gen', 10].plot()
results_df['high_risk', 'gen', 10].plot(style='--')
results_df['vulnerability', 'gen', 10].plot(style='-')
results_df['random', 'gen', 10].plot(style='--', linewidth=4)
results_no_intervention_df['General (no interventions)'].plot()
plt.ylim(1.5,1.75)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend()

plt.subplot(312)
plt.title('General Question (15%)')
results_df['optimized', 'gen', 15].plot()
results_df['centrality', 'gen', 15].plot()
results_df['high_risk', 'gen', 15].plot(style='--')
results_df['vulnerability', 'gen', 15].plot(style='-')
results_df['random', 'gen', 15].plot(style='--', linewidth=4)
results_no_intervention_df['General (no interventions)'].plot()
plt.ylim(1.5,1.75)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend()

plt.subplot(313)
plt.title('General Question (20%)')
results_df['optimized', 'gen', 20].plot()
results_df['centrality', 'gen', 20].plot()
results_df['high_risk', 'gen', 20].plot(style='--')
results_df['vulnerability', 'gen', 20].plot(style='-')
results_df['random', 'gen', 20].plot(style='--', linewidth=4)
results_no_intervention_df['General (no interventions)'].plot()
plt.ylim(1.5,1.75)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend()

# %%
plt.figure(figsize=((14,22)))
plt.subplot(311)
plt.title('Friendship Question (10%)')
results_df['optimized', 'friend', 10].plot()
results_df['centrality', 'friend', 10].plot()
results_df['high_risk', 'friend', 10].plot(style='--')
results_df['vulnerability', 'friend', 10].plot(style='-')
results_df['random', 'friend', 10].plot(style='--')
results_no_intervention_df['Friend (no interventions)'].plot()
plt.legend()

plt.subplot(312)
plt.title('Friendship Question (15%)')
results_df['optimized', 'friend', 15].plot()
results_df['centrality', 'friend', 15].plot()
results_df['high_risk', 'friend', 15].plot(style='--')
results_df['vulnerability', 'friend', 15].plot(style='-')
results_df['random', 'friend', 15].plot(style='--')
results_no_intervention_df['Friend (no interventions)'].plot()
plt.legend()

plt.subplot(313)
plt.title('Friendship Question (20%)')
results_df['optimized', 'friend', 20].plot()
results_df['centrality', 'friend', 20].plot()
results_df['high_risk', 'friend', 20].plot(style='--')
results_df['vulnerability', 'friend', 20].plot(style='-')
results_df['random', 'friend', 20].plot(style='--')
results_no_intervention_df['Friend (no interventions)'].plot()
plt.legend()

# %%
plt.figure(figsize=((14,22)))

plt.subplot(311)
plt.title('Optimized (All questions)')
results_df['optimized', 'all', 10].plot()
results_df['optimized', 'all', 15].plot()
results_df['optimized', 'all', 20].plot()
results_no_intervention_df['All (no interventions)'].plot()
plt.legend()

plt.subplot(312)
plt.title('Optimized (General questions)')
results_df['optimized', 'gen', 10].plot()
results_df['optimized', 'gen', 15].plot()
results_df['optimized', 'gen', 20].plot()
results_no_intervention_df['General (no interventions)'].plot()
plt.legend()

plt.subplot(313)
plt.title('Optimized (Friendship question)')
results_df['optimized', 'friend', 10].plot()
results_df['optimized', 'friend', 15].plot()
results_df['optimized', 'friend', 20].plot()
results_no_intervention_df['Friend (no interventions)'].plot()
plt.legend()

# %%
plt.figure(figsize=((14,22)))

plt.subplot(311)
plt.title('Centrality (All questions)')
results_df['centrality', 'all', 10].plot()
results_df['centrality', 'all', 15].plot()
results_df['centrality', 'all', 20].plot()
results_no_intervention_df['All (no interventions)'].plot()
plt.legend()

plt.subplot(312)
plt.title('centrality (General questions)')
results_df['centrality', 'gen', 10].plot()
results_df['centrality', 'gen', 15].plot()
results_df['centrality', 'gen', 20].plot()
results_no_intervention_df['General (no interventions)'].plot()
plt.legend()

plt.subplot(313)
plt.title('centrality (Friendship question)')
results_df['centrality', 'friend', 10].plot()
results_df['centrality', 'friend', 15].plot()
results_df['centrality', 'friend', 20].plot()
results_no_intervention_df['Friend (no interventions)'].plot()
plt.legend()

# %%
# Random results
plt.figure(figsize=((10,30)))
plt.subplot(311)
plt.title('Results for random selection of the nodes')
results_df['random', 'all', 10].plot(style='-.', color='black')
#results_df['random', 'gen', 10].plot(style='-.', color='blue')
#results_df['random', 'friend', 10].plot(style='-.', color='green')

results_df['random', 'all', 15].plot(style=':', linewidth=3, color='black')
#results_df['random', 'gen', 15].plot(style=':', linewidth=3, color='blue')
#results_df['random', 'friend', 15].plot(style=':', linewidth=3, color='green')

results_df['random', 'all', 20].plot(color='black')
#results_df['random', 'gen', 20].plot(color='blue')
#results_df['random', 'friend', 20].plot(color='green')

results_no_intervention_df['All (no interventions)'].plot(style='-', linewidth=5, color='black')
#results_no_intervention_df['General (no interventions)'].plot(style='-', linewidth=5, color='blue')
#results_no_intervention_df['Friend (no interventions)'].plot(style='-', linewidth=5, color='green')

plt.ylim(1.5,1.75)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(loc=4, title='Network: All questions')

# %%
# Random results
plt.figure(figsize=((10,30)))
plt.subplot(311)
plt.title('Results for the selection of the nodes with high risk')
results_df['high_risk', 'all', 10].plot(style='-.', color='black')
#results_df['high_risk', 'gen', 10].plot(style='-.', color='blue')
#results_df['high_risk', 'friend', 10].plot(style='-.', color='green')

results_df['high_risk', 'all', 15].plot(style=':', linewidth=4, color='black')
#results_df['high_risk', 'gen', 15].plot(style=':', linewidth=4, color='blue')
#results_df['high_risk', 'friend', 15].plot(style=':', linewidth=4, color='green')

results_df['high_risk', 'all', 20].plot(color='black')
#results_df['high_risk', 'gen', 20].plot(color='blue')
#results_df['high_risk', 'friend', 20].plot(color='green')

results_no_intervention_df['All (no interventions)'].plot(style='-', linewidth=5, color='black')
#results_no_intervention_df['General (no interventions)'].plot(style='-', linewidth=5, color='blue')
#results_no_intervention_df['Friend (no interventions)'].plot(style='-', linewidth=5, color='green')
plt.ylim(1.5,1.8)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(loc=4, title='Network: All questions')

# %%
# Random results
plt.figure(figsize=((10,30)))
plt.subplot(311)
plt.title('Results for the selection of the nodes with high vulnerability')
results_df['vulnerability', 'all', 10].plot(style='-.', color='black')
#results_df['vulnerability', 'gen', 10].plot(style='-.', color='blue')
#results_df['vulnerability', 'friend', 10].plot(style='-.', color='green')

results_df['vulnerability', 'all', 15].plot(style=':', linewidth=4, color='black')
#results_df['vulnerability', 'gen', 15].plot(style=':', linewidth=4, color='blue')
#results_df['vulnerability', 'friend', 15].plot(style=':', linewidth=4, color='green')

results_df['vulnerability', 'all', 20].plot(color='black')
#results_df['vulnerability', 'gen', 20].plot(color='blue')
#results_df['vulnerability', 'friend', 20].plot(color='green')

results_no_intervention_df['All (no interventions)'].plot(style='-', linewidth=5, color='black')
#results_no_intervention_df['General (no interventions)'].plot(style='-', linewidth=5, color='blue')
#results_no_intervention_df['Friend (no interventions)'].plot(style='-', linewidth=5, color='green')
plt.ylim(1.5,1.8)
plt.xlim(0,364)
plt.xlabel('Days')
plt.ylabel('Mean PA')
plt.legend(loc=4, title='Network: All questions')

# %% [markdown]
# # Differences beginning and end

# %%
# High Risk
print((results_df['high_risk', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['high_risk', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.04910899078935671 0.04689594389824747

# %%
print((results_df['vulnerability', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['vulnerability', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.05145567623614178 0.08706611318172697

# %%
print((results_df['random', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['random', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.051592534368060106 0.055988212403567106

# %%
print((results_df['centrality', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['centrality', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.0548189345620842 0.06229391710548815

# %%
print((results_df['optimized', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['optimized', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.050842420799334764 0.098452541886354

# %% [markdown]
# # Differences and percentages

# %%
print((results_df['high_risk', 'all', 10] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['high_risk', 'all', 10] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['high_risk', 'all', 15] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['high_risk', 'all', 15] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['high_risk', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['high_risk', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.02497420894124147 0.022527023402078683
# 0.03742821506208416 0.037138577386700344
# 0.04910899078935671 0.04689594389824747

# %%
print((results_df['random', 'all', 10] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['random', 'all', 10] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['random', 'all', 15] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['random', 'all', 15] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['random', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['random', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.025625256235211058 0.028577069356110263
# 0.03979795573057565 0.043850998901424854
# 0.051592534368060106 0.055988212403567106

# %%
print((results_df['vulnerability', 'all', 10] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['vulnerability', 'all', 10] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['vulnerability', 'all', 15] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['vulnerability', 'all', 15] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['vulnerability', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['vulnerability', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.0266577441585365 0.056029642951624714
# 0.04077545887915712 0.07181992681293137
# 0.05145567623614178 0.08706611318172697

# %%
print((results_df['centrality', 'all', 10] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['centrality', 'all', 10] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['centrality', 'all', 15] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['centrality', 'all', 15] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['centrality', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['centrality', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.027994340963414688 0.036202981329821915
# 0.04176416088026613 0.05028516902137281
# 0.0548189345620842 0.06229391710548815

# %%
print((results_df['optimized', 'all', 10] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['optimized', 'all', 10] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['optimized', 'all', 15] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['optimized', 'all', 15] - results_no_intervention_df['All (no interventions)'])[364])
print((results_df['optimized', 'all', 20] - results_no_intervention_df['All (no interventions)'])[0], 
      (results_df['optimized', 'all', 20] - results_no_intervention_df['All (no interventions)'])[364])
# Out:
# 0.02680530909645218 0.06501969435076305
# 0.040117002176274896 0.08632674605035895
# 0.050842420799334764 0.098452541886354

# %%
results_df.to_csv('./results/final/table_interventions.csv')
pd.DataFrame(results_no_intervention)
